# %% [markdown]
# ### Introduction to Machine Learning with Python
# ## Chapter 1. 소개
# ---
# # Numpy를 활용한 수치근사법 예제

# %%
# %pylab inline

import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### sklearn 의 make_blobs 함수를 사용

# %%
from sklearn.datasets import make_blobs

# %%
data, label = make_blobs(n_samples=500, centers=[[0,0]])

# %%
plt.hlines([0],-10,10,linestyles='dotted')
plt.vlines([0],-10,10,linestyles='dotted')
plt.scatter(data[:,0], data[:,1], alpha=0.3)
plt.axis('scaled')
# Out:
# (-11.0, 11.0, -11.0, 11.0)

# %%
data = data * [3,1]

plt.hlines([0],-10,10,linestyles='dotted')
plt.vlines([0],-10,10,linestyles='dotted')
plt.scatter(data[:,0], data[:,1], alpha=0.3)
plt.axis('scaled')
# Out:
# (-11.0, 11.0, -11.0, 11.0)

# %% [markdown]
# ### np.random.randn() 사용

# %%
X = np.random.randn(500) * 3
y = X + np.random.randn(500)

plt.hlines([0],-10,10,linestyles='dotted')
plt.vlines([0],-10,10,linestyles='dotted')
plt.scatter(X, y, alpha=0.3)
plt.axis('scaled')
# Out:
# (-11.0, 11.0, -11.0, 11.0)

# %%
X = X + 5
y = y + 5

plt.hlines([0],-10,10,linestyles='dotted')
plt.vlines([0],-10,10,linestyles='dotted')
plt.scatter(X, y, alpha=0.3)
plt.axis('scaled')
# Out:
# (-11.185299577232835,
#  14.891291121889513,
#  -11.16168792527185,
#  14.395446430708867)

# %%
plt.hlines([0],-10,10,linestyles='dotted')
plt.vlines([0],-10,10,linestyles='dotted')
plt.scatter(X, y, alpha=0.3, label='samples')
plt.axis('scaled')

plt.plot([-10,10],[-10,10], 'r--', label='predict line')
plt.legend()

# %%
display(X.shape, y.shape)
display(X[:5], y[:5])
# Out:
# (500,)
# (500,)
# array([6.61903221, 1.51399881, 7.52153143, 8.50300919, 5.51345363])
# array([6.51883719, 1.29075528, 7.51171393, 7.18195737, 5.23779876])

# %%
pred_y = X

Cost = ((pred_y - y)**2).sum() / len(y)
Cost
# Out:
# 1.0568815775228513

# %%
pred_y = X * 0.99

Cost = ((pred_y - y)**2).sum() / len(y)
Cost
# Out:
# 1.0612919306441468

# %%
ws = np.arange(0, 2.001, 0.1) # 기울기 범위
costs = []
min_cost = np.inf
min_w = None

for w in ws:
    pred_y = X * w
    cost = ((pred_y - y)**2).sum() / len(y)
    costs.append(cost)
    
    if cost<min_cost :
        min_cost = cost
        min_w = w
        
display(min_w, min_cost)
# Out:
# 1.0
# 1.0568815775228513

# %%
plt.plot(ws, costs, 'o-')
plt.xticks(ws, rotation=90)
plt.xlabel('w', fontsize=20)
plt.ylabel('cost', fontsize=20)
plt.title('Cost Function', fontsize=20)
# Out:
# Text(0.5,1,'Cost Function')

# %% [markdown]
# ### 비용함수(cost)는 기울기(w) 에 대한 이차다항식
#
# $$ \hat{y_i} = w \cdot x_i $$
# $$ cost = \frac{1}{N} \sum_{i=0}^{N-1} (\hat{y_i} - y_i)^2 $$
# $$ = \frac{1}{N} \sum_{i=0}^{N-1} (w \cdot x_i - y_i)^2 $$
# $$ = (\frac{1}{N} \sum_{i=0}^{N-1} x_i^2) \cdot w^2 -
# (\frac{2}{N} \sum_{i=0}^{N-1} x_i \cdot y_i) \cdot w +
# (\frac{1}{N} \sum_{i=0}^{N-1} y_i^2) $$
