# %% [markdown]
# ## Chapter 7
# # 데이터 준비하기: 다듬기, 변형, 병합
# ---
# ## 미국 농무부 음식 데이터베이스

# %%
# %pylab inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['info', 'f']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import json

f = open('foods-2011-10-03.json')
data = json.load(f)
f.close()

# %%
type(data), len(data)
data[0].keys() # ['group', 'manufacturer', 'description', 'nutrients', 'portions', 'id', 'tags']

df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6636 entries, 0 to 6635
# Data columns (total 7 columns):
# description     6636 non-null object
# group           6636 non-null object
# id              6636 non-null int64
# manufacturer    5195 non-null object
# nutrients       6636 non-null object
# portions        6636 non-null object
# tags            6636 non-null object
# dtypes: int64(1), object(6)
# memory usage: 207.4+ KB

# %%
df[:5]
# Out:
#                           description                   group    id  \
# 0                     Cheese, caraway  Dairy and Egg Products  1008
# 1                     Cheese, cheddar  Dairy and Egg Products  1009
# 2                        Cheese, edam  Dairy and Egg Products  1018
# 3                        Cheese, feta  Dairy and Egg Products  1019
# 4  Cheese, mozzarella, part skim milk  Dairy and Egg Products  1028
#
#   manufacturer                                          nutrients  \
# 0               [{'units': 'g', 'value': 25.18, 'group': 'Comp...
# 1               [{'units': 'g', 'value': 24.9, 'group': 'Compo...
# 2               [{'units': 'g', 'value': 4.22, 'group': 'Other...
# 3               [{'units': 'g', 'value': 5.2, 'group': 'Other'...
# 4               [{'units': 'g', 'value': 3.27, 'group': 'Other...
#
#                                             portions tags
# 0      [{'grams': 28.35, 'amount': 1, 'unit': 'oz'}]   []
# 1  [{'grams': 132.0, 'amount': 1, 'unit': 'cup, d...   []
# 2  [{'grams': 28.35, 'amount': 1, 'unit': 'oz'}, ...   []
# 3  [{'grams': 150.0, 'amount': 1, 'unit': 'cup, c...   []
# 4      [{'grams': 28.35, 'amount': 1, 'unit': 'oz'}]   []

# %%
info = pd.DataFrame(data, columns = ['description','group','id','manufacturer'])
info.head()
# Out:
#                           description                   group    id  \
# 0                     Cheese, caraway  Dairy and Egg Products  1008
# 1                     Cheese, cheddar  Dairy and Egg Products  1009
# 2                        Cheese, edam  Dairy and Egg Products  1018
# 3                        Cheese, feta  Dairy and Egg Products  1019
# 4  Cheese, mozzarella, part skim milk  Dairy and Egg Products  1028
#
#   manufacturer
# 0
# 1
# 2
# 3
# 4

# %%
info2 = info.take(info.id.argsort()).reset_index(drop=True)
info2['old_index']=info.id.argsort()
info2.head(10)
# Out:
#                                         description                   group  \
# 0                                   Cheese, caraway  Dairy and Egg Products
# 1                                   Cheese, cheddar  Dairy and Egg Products
# 2                                      Cheese, edam  Dairy and Egg Products
# 3                                      Cheese, feta  Dairy and Egg Products
# 4                          Spices, allspice, ground        Spices and Herbs
# 5                                Spices, anise seed        Spices and Herbs
# 6                              Spices, basil, dried        Spices and Herbs
# 7                Cheese, mozzarella, part skim milk  Dairy and Egg Products
# 8  Cheese, mozzarella, part skim milk, low moisture  Dairy and Egg Products
# 9                                  Spices, cardamom        Spices and Herbs
#
#      id manufacturer  old_index
# 0  1008                       0
# 1  1009                       1
# 2  1018                       2
# 3  1019                       3
# 4  1025                      73
# 5  1026                      74
# 6  1027                      75
# 7  1028                       4
# 8  1029                       5
# 9  1030                      76

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6636 entries, 0 to 6635
# Data columns (total 4 columns):
# description     6636 non-null object
# group           6636 non-null object
# id              6636 non-null int64
# manufacturer    5195 non-null object
# dtypes: int64(1), object(3)
# memory usage: 129.6+ KB

# %%
(info.manufacturer.str.strip()=='').sum() # 4132
info.manufacturer.isnull().sum() # 1441
# Out:
# 1441

# %%
pd.value_counts(info.group)
# Out:
# Vegetables and Vegetable Products    812
# Beef Products                        618
# Baked Products                       496
# Breakfast Cereals                    403
# Fast Foods                           365
# Legumes and Legume Products          365
# Lamb, Veal, and Game Products        345
# Sweets                               341
# Fruits and Fruit Juices              328
# Pork Products                        328
# Beverages                            278
# Soups, Sauces, and Gravies           275
# Finfish and Shellfish Products       255
# Baby Foods                           209
# Cereal Grains and Pasta              183
# Ethnic Foods                         165
# Snacks                               162
# Nut and Seed Products                128
# Poultry Products                     116
# Sausages and Luncheon Meats          111
# Dairy and Egg Products               107
# Fats and Oils                         97
# Meals, Entrees, and Sidedishes        57
# Restaurant Foods                      51
# Spices and Herbs                      41
# Name: group, dtype: int64

# %%
l = []

for d in data:
    n = pd.DataFrame(d['nutrients'])
    n['id'] = d['id']
    l.append(n)

# %%
nutrients = pd.concat(l, ignore_index=True)
display(nutrients.shape, nutrients.head())
# Out:
# (389355, 5)
#                    description        group units   value    id
# 0                      Protein  Composition     g   25.18  1008
# 1            Total lipid (fat)  Composition     g   29.20  1008
# 2  Carbohydrate, by difference  Composition     g    3.06  1008
# 3                          Ash        Other     g    3.28  1008
# 4                       Energy       Energy  kcal  376.00  1008

# %%
df = pd.DataFrame(np.arange(9).reshape(3,3))
pd.concat([df,df], ignore_index=True)
# Out:
#    0  1  2
# 0  0  1  2
# 1  3  4  5
# 2  6  7  8
# 3  0  1  2
# 4  3  4  5
# 5  6  7  8

# %%
nutrients.duplicated().sum()
# Out:
# 14179

# %%
nutrients = nutrients.drop_duplicates()
nutrients = nutrients.rename(columns={'description':'nutrient', 'group':'nutgroup'})

display(nutrients.shape, nutrients.head())
# Out:
# (375176, 5)
#                       nutrient     nutgroup units   value    id
# 0                      Protein  Composition     g   25.18  1008
# 1            Total lipid (fat)  Composition     g   29.20  1008
# 2  Carbohydrate, by difference  Composition     g    3.06  1008
# 3                          Ash        Other     g    3.28  1008
# 4                       Energy       Energy  kcal  376.00  1008

# %%
info = info.rename(columns={'description':'food','group':'fgroup'})
info.head()
# Out:
#                                  food                  fgroup    id  \
# 0                     Cheese, caraway  Dairy and Egg Products  1008
# 1                     Cheese, cheddar  Dairy and Egg Products  1009
# 2                        Cheese, edam  Dairy and Egg Products  1018
# 3                        Cheese, feta  Dairy and Egg Products  1019
# 4  Cheese, mozzarella, part skim milk  Dairy and Egg Products  1028
#
#   manufacturer
# 0
# 1
# 2
# 3
# 4

# %%
ndata = pd.merge(nutrients,info,on='id',how='outer')
display(ndata.shape, ndata.head())
# Out:
# (375176, 8)
#                       nutrient     nutgroup units   value    id  \
# 0                      Protein  Composition     g   25.18  1008
# 1            Total lipid (fat)  Composition     g   29.20  1008
# 2  Carbohydrate, by difference  Composition     g    3.06  1008
# 3                          Ash        Other     g    3.28  1008
# 4                       Energy       Energy  kcal  376.00  1008
#
#               food                  fgroup manufacturer
# 0  Cheese, caraway  Dairy and Egg Products
# 1  Cheese, caraway  Dairy and Egg Products
# 2  Cheese, caraway  Dairy and Egg Products
# 3  Cheese, caraway  Dairy and Egg Products
# 4  Cheese, caraway  Dairy and Egg Products

# %%
result = ndata.groupby(['nutrient','fgroup'])['value'].quantile(0.5)
result.head()
# Out:
# nutrient          fgroup
# Adjusted Protein  Sweets                               12.900
#                   Vegetables and Vegetable Products     2.180
# Alanine           Baby Foods                            0.085
#                   Baked Products                        0.248
#                   Beef Products                         1.550
# Name: value, dtype: float64

# %%
result['Zinc, Zn'].sort_values().plot(kind='barh')

# %%
max_foods = ndata.groupby(['nutrient','nutgroup']).apply(lambda x: x.xs(x.value.idxmax()))[['value','food']]
max_foods.head()
# Out:
#                                value  \
# nutrient         nutgroup
# Adjusted Protein Composition  12.900
# Alanine          Amino Acids   8.009
# Alcohol, ethyl   Other        42.500
# Arginine         Amino Acids   7.436
# Ash              Other        72.500
#
#                                                                            food
# nutrient         nutgroup
# Adjusted Protein Composition             Baking chocolate, unsweetened, squares
# Alanine          Amino Acids                  Gelatins, dry powder, unsweetened
# Alcohol, ethyl   Other        Alcoholic beverage, distilled, all (gin, rum, ...
# Arginine         Amino Acids                       Seeds, sesame flour, low-fat
# Ash              Other                   Desserts, rennin, tablets, unsweetened

# %%
max_foods.loc[(slice(None),'Amino Acids'),:] # max_foods.loc[pd.IndexSlice[:, 'Amino Acids'],:]
# Out:
#                              value  \
# nutrient       nutgroup
# Alanine        Amino Acids   8.009
# Arginine       Amino Acids   7.436
# Aspartic acid  Amino Acids  10.203
# Cystine        Amino Acids   1.307
# Glutamic acid  Amino Acids  17.452
# Glycine        Amino Acids  19.049
# Histidine      Amino Acids   2.999
# Hydroxyproline Amino Acids   0.803
# Isoleucine     Amino Acids   4.300
# Leucine        Amino Acids   7.200
# Lysine         Amino Acids   6.690
# Methionine     Amino Acids   1.859
# Phenylalanine  Amino Acids   4.600
# Proline        Amino Acids  12.295
# Serine         Amino Acids   4.600
# Threonine      Amino Acids   3.300
# Tryptophan     Amino Acids   1.600
# Tyrosine       Amino Acids   3.300
# Valine         Amino Acids   4.500
#
#                                                                          food
# nutrient       nutgroup
# Alanine        Amino Acids                  Gelatins, dry powder, unsweetened
# Arginine       Amino Acids                       Seeds, sesame flour, low-fat
# Aspartic acid  Amino Acids                                Soy protein isolate
# Cystine        Amino Acids       Seeds, cottonseed flour, low fat (glandless)
# Glutamic acid  Amino Acids                                Soy protein isolate
# Glycine        Amino Acids                  Gelatins, dry powder, unsweetened
# Histidine      Amino Acids         Whale, beluga, meat, dried (Alaska Native)
# Hydroxyproline Amino Acids  KENTUCKY FRIED CHICKEN, Fried Chicken, ORIGINA...
# Isoleucine     Amino Acids  Soy protein isolate, PROTEIN TECHNOLOGIES INTE...
# Leucine        Amino Acids  Soy protein isolate, PROTEIN TECHNOLOGIES INTE...
# Lysine         Amino Acids  Seal, bearded (Oogruk), meat, dried (Alaska Na...
# Methionine     Amino Acids              Fish, cod, Atlantic, dried and salted
# Phenylalanine  Amino Acids  Soy protein isolate, PROTEIN TECHNOLOGIES INTE...
# Proline        Amino Acids                  Gelatins, dry powder, unsweetened
# Serine         Amino Acids  Soy protein isolate, PROTEIN TECHNOLOGIES INTE...
# Threonine      Amino Acids  Soy protein isolate, PROTEIN TECHNOLOGIES INTE...
# Tryptophan     Amino Acids   Sea lion, Steller, meat with fat (Alaska Native)
# Tyrosine       Amino Acids  Soy protein isolate, PROTEIN TECHNOLOGIES INTE...
# Valine         Amino Acids  Soy protein isolate, PROTEIN TECHNOLOGIES INTE...
