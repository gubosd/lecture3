# %% [markdown]
# ### Introduction to Machine Learning with Python
# ## Chapter 0. 사전 준비
# ---
# # 거리(distance) 개념

# %%
# %pylab inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s = open('iris.csv').readline()
columns = [i.strip('"') for i in s.strip().split(',')][:-1]
columns
# Out:
# ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']

# %%
mapper = {'"Setosa"': 0, '"Versicolor"': 1, '"Virginica"': 2}
iris = np.loadtxt('iris.csv', delimiter=',', skiprows=1, converters={4: lambda s: mapper[s.decode()]})

# %%
display(iris.shape, iris[:5])
# Out:
# (150, 5)
# array([[5.1, 3.5, 1.4, 0.2, 0. ],
#        [4.9, 3. , 1.4, 0.2, 0. ],
#        [4.7, 3.2, 1.3, 0.2, 0. ],
#        [4.6, 3.1, 1.5, 0.2, 0. ],
#        [5. , 3.6, 1.4, 0.2, 0. ]])

# %%
X = iris[:,:4]
y = iris[:,4]

# %% [markdown]
# ### 두 점 간의 거리 계산 공식
# $$ distance(x_1, x_2) = \sqrt {\sum_{i=0}^{N-1} (x_{1i} - x_{2i})^2},\ N = \#\ of\ features $$

# %%
x1 = X[0]
x2 = X[1]
display(x1, x2)

distance = np.sqrt(((x1-x2)**2).sum())
distance
# Out:
# array([5.1, 3.5, 1.4, 0.2])
# array([4.9, 3. , 1.4, 0.2])
# 0.5385164807134502

# %%
x1 = x1[:2]
x2 = x2[:2]

display(x1, x2)
plt.plot([x1[0],x2[0]], [x1[1],x2[1]], 'bo--')
plt.axis('equal')
# Out:
# array([5.1, 3.5])
# array([4.9, 3. ])
# (4.890000000000001, 5.109999999999999, 2.975, 3.525)

# %%
distance = np.sqrt(((x1-x2)**2).sum())
distance
# Out:
# 0.5385164807134502

# %%
(4)+1
# Out:
# 5

# %% [markdown]
# ### 한점과 다른 모든 점들 간의 거리 계산

# %%
distance = np.sqrt(((X - X[0])**2).sum(axis=1))
distance[:5]
# Out:
# array([0.        , 0.53851648, 0.50990195, 0.64807407, 0.14142136])

# %%
plt.figure(figsize=[10,4])
plt.plot(distance, 'bo-')
plt.xlabel('samples', fontsize=15)
plt.ylabel('distance', fontsize=15)
plt.xticks(range(0,151,25), [0, 'Setosa', 50, 'Versicolor', 75, 'Virginica', 150])
plt.yticks(range(0,8))
plt.grid()
# plt.vlines([50,100], 0, 10, linestyles='dotted')
plt.title('distances from X[0]', fontsize=20)
# Out:
# Text(0.5,1,'distances from X[0]')

# %%
7/150
# Out:
# 0.04666666666666667
