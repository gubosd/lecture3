# %% [markdown]
# ## Chapter 8
# # 도식화와 시각화
# ---
# ## matplotlib 기초

# %% [markdown]
# ### 시각화의 중요성과 matplotlib
# - 인간은 가장 시각 능력이 뛰어난 동물 중의 하나이다.
# - 하지만 인간의 수치 계산 능력은 본능이 아니다. (언어의 발달로 인한 논리 능력의 확장임)
# - 이런 점들이 인간이 아직까지 인공지능에 비해 시각적 판단이 뛰어난 이유이다.
# - 시각 능력은 다른 말로 하면 **패턴인식** 능력이다. 빛의 분포로 생기는 시각 패턴을 인간은 너무나 쉽게 알아 볼 수 있다.
# - 이러한 인간의 능력을 최대한 발휘하기 위해서 숫자로 되어 있는 데이터를 시각화 하여야 한다.
# - 제공받은 데이터의 **특성을 분석**하기 위해서 뿐만 아니라, **결과를 설명**하기 위해서 시각화는 아주 중요하다.
# - matplotlib 는 파이썬의 시각화 도구이다.
# - matplotlib 는 MATLAB 의 시각화 기능을 참고하여 만들어졌다.
# - matplotlib 는 3차원 시각화 도구를 제공하지만 평면 상에서 3차원 도표는 알아보기 쉽지 않으므로, 대부분의 시각화 기능은 2차원을 위주로 한다.

# %% [markdown]
# ### 참고 자료
# - 홈페이지 : https://matplotlib.org/
# - 튜토리얼 : https://matplotlib.org/tutorials/introductory/pyplot.html
# - API : https://matplotlib.org/api/index.html
# - 예제 : https://matplotlib.org/tutorials/index.html#introductory

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
plt.show()

# %%
plt.plot(np.random.randn(100))

# %% [markdown]
# **[주의]**
# - %pylab inline 또는 %matplotlib inline 을 실행하면 ipython 과 쥬피터 노트북에서 plt.show() 를 실행하지 않아도 되고 도표가 실행창에 포함된다.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4])
plt.plot([4,3,2,1])

# %%
plt.plot([1,2,3,4], label='up')
plt.plot([4,3,2,1], label='down')
plt.legend()

# %%
plt.plot([1,2,3,4], label='up')
plt.plot([4,3,2,1], label='down')
plt.legend(loc='best')
plt.axis([-1,4,0,5])
# Out:
# [-1, 4, 0, 5]

# %% [markdown]
# - 도표에 제목을 붙이자.

# %%
plt.plot([1,2,3,4], label='up')
plt.plot([4,3,2,1], label='down')
plt.legend(loc='best')
plt.axis([-1,4,0,5])

plt.title('UP and DOWN lines', fontsize=20)
plt.xlabel('X')
plt.ylabel('value')
# Out:
# Text(0,0.5,'value')

# %% [markdown]
# - 이미지 크기를 변경하자.

# %%
fig = plt.figure(figsize=[12,8])

plt.plot([1,2,3,4], label='up')
plt.plot([4,3,2,1], label='down')
plt.legend(loc='best')
plt.axis('scaled')
plt.axis([-1,4,0,5])
#plt.xlim(-1,4)
#plt.ylim(0,5)

plt.title('UP and DOWN lines', fontsize=20)
plt.xlabel('X')
plt.ylabel('value')

plt.xticks([0,1.5,3],['one','1 1/2', 'three'])
plt.yticks(np.arange(1,4.1,0.5))
plt.grid()

# %% [markdown]
# ### plot() 함수
# - https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %%
a=np.random.randn(100)

plt.plot(a)
plt.plot(a.cumsum())
plt.legend(['original','cumsum'])

# %%
plt.plot(a, 'b--') # color='b', linestyle='--'
plt.plot(a.cumsum(), 'ro-') # color='red', marker='o', linestyle='-'
plt.legend(['original','cumsum'], loc='best')

# %%
plt.plot(a[:10], 'r^-', linewidth=3, markersize=10)
plt.plot(a[:10], 'g:', drawstyle='steps-post')

# %%
N = 10000
a = np.random.randn(N)
plt.plot(a.cumsum())

# %%
plt.plot([0,1,2,3], label='p1')
plt.plot([1,2,3,4])
plt.plot([2,3,4,5], label='p3')

plt.xticks(range(4),rotation=30, ha='left')
plt.legend()

# %%
plt.plot([1,3,2,4], [1,2,3,4])
plt.axis([0,5,0,5])
# Out:
# [0, 5, 0, 5]

# %%
a = np.array([[1,2,3],[10,11,12]])
plt.plot(a) # 열 단위로 그린다

plt.figure() # 전체 그림을 리셋한다
plt.plot(a.T)
# Out:
# [<matplotlib.lines.Line2D at 0x81b6ef0>,
#  <matplotlib.lines.Line2D at 0x81b6748>]

# %% [markdown]
# ### scatter() 함수
# - 산점도 그림을 그린다.
# - 보통 속성이 2개인 샘플들의 위치를 점으로 찍는다.

# %%
a = np.array([[1,1], [2,3], [3,2]])
plt.scatter(a[:,0], a[:,1]) # 각각 X축과 Y축

# %%
x = np.random.randn(10000)
y = np.random.randn(10000)
plt.scatter(x,y, alpha=0.05)
plt.axis('scaled')
# Out:
# (-4.056557306134831, 4.345963982691481, -4.041367621854011, 4.038260876510021)

# %%
x1 = np.random.normal(0,3,500)
y1 = np.random.normal(0,3,500)
plt.scatter(x1,y1, alpha=0.2, cmap='gray')

x2 = np.random.normal(10,3,500)
y2 = np.random.normal(5,2,500)
plt.scatter(x2,y2, alpha=0.2, cmap='gray')

plt.legend(['one','two'])

# %%
help(plt.scatter)
# Out:
# Help on function scatter in module matplotlib.pyplot:
#
# scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=None, edgecolors=None, hold=None, data=None, **kwargs)
#     A scatter plot of *y* vs *x* with varying marker size and/or color.
#
#     Parameters
#     ----------
#     x, y : array_like, shape (n, )
#         The data positions.
#
#     s : scalar or array_like, shape (n, ), optional
#         The marker size in points**2.
#         Default is ``rcParams['lines.markersize'] ** 2``.
#
#     c : color, sequence, or sequence of color, optional, default: 'b'
#         The marker color. Possible values:
#
#         - A single color format string.
#         - A sequence of color specifications of length n.
#         - A sequence of n numbers to be mapped to colors using *cmap* and
#           *norm*.
#         - A 2-D array in which the rows are RGB or RGBA.
#
#         Note that *c* should not be a single numeric RGB or RGBA sequence
#         because that is indistinguishable from an array of values to be
#         colormapped. If you want to specify the same RGB or RGBA value for
#         all points, use a 2-D array with a single row.
#
#     marker : `~matplotlib.markers.MarkerStyle`, optional, default: 'o'
#         The marker style. *marker* can be either an instance of the class
#         or the text shorthand for a particular marker.
#         See `~matplotlib.markers` for more information marker styles.
#
#     cmap : `~matplotlib.colors.Colormap`, optional, default: None
#         A `.Colormap` instance or registered colormap name. *cmap* is only
#         used if *c* is an array of floats. If ``None``, defaults to rc
#         ``image.cmap``.
#
#     norm : `~matplotlib.colors.Normalize`, optional, default: None
#         A `.Normalize` instance is used to scale luminance data to 0, 1.
#         *norm* is only used if *c* is an array of floats. If *None*, use
#         the default `.colors.Normalize`.
#
#     vmin, vmax : scalar, optional, default: None
#         *vmin* and *vmax* are used in conjunction with *norm* to normalize
#         luminance data. If None, the respective min and max of the color
#         array is used. *vmin* and *vmax* are ignored if you pass a *norm*
#         instance.
#
#     alpha : scalar, optional, default: None
#         The alpha blending value, between 0 (transparent) and 1 (opaque).
#
#     linewidths : scalar or array_like, optional, default: None
#         The linewidth of the marker edges. Note: The default *edgecolors*
#         is 'face'. You may want to change this as well.
#         If *None*, defaults to rcParams ``lines.linewidth``.
#
#     verts : sequence of (x, y), optional
#         If *marker* is *None*, these vertices will be used to construct
#         the marker.  The center of the marker is located at (0, 0) in
#         normalized units.  The overall marker is rescaled by *s*.
#
#     edgecolors : color or sequence of color, optional, default: 'face'
#         The edge color of the marker. Possible values:
#
#         - 'face': The edge color will always be the same as the face color.
#         - 'none': No patch boundary will be drawn.
#         - A matplotib color.
#
#         For non-filled markers, the *edgecolors* kwarg is ignored and
#         forced to 'face' internally.
#
#     Returns
#     -------
#     paths : `~matplotlib.collections.PathCollection`
#
#     Other Parameters
#     ----------------
#     **kwargs : `~matplotlib.collections.Collection` properties
#
#     See Also
#     --------
#     plot : To plot scatter plots when markers are identical in size and
#         color.
#
#     Notes
#     -----
#
#     * The `.plot` function will be faster for scatterplots where markers
#       don't vary in size or color.
#
#     * Any or all of *x*, *y*, *s*, and *c* may be masked arrays, in which
#       case all masks will be combined and only unmasked points will be
#       plotted.
#
#     * Fundamentally, scatter works with 1-D arrays; *x*, *y*, *s*, and *c*
#       may be input as 2-D arrays, but within scatter they will be
#       flattened. The exception is *c*, which will be flattened only if its
#       size matches the size of *x* and *y*.
#
#     .. note::
#         In addition to the above described arguments, this function can take a
#         **data** keyword argument. If such a **data** argument is given, the
#         following arguments are replaced by **data[<arg>]**:
#
#         * All arguments with the following names: 'c', 'color', 'edgecolors', 'facecolor', 'facecolors', 'linewidths', 's', 'x', 'y'.

# %%
plt.figure(figsize=[12,12])
# x = np.random.rand(1000)
x = np.random.uniform(-5,5,size=1000)
y = 2*x + 1 + np.random.randn(1000)
plt.scatter(x,y, alpha=0.2)
plt.vlines([0],-5,5, linestyles=':')
plt.hlines([0],-3,3, linestyles=':')
plt.axis('equal')
# Out:
# (-5.496987682047008, 5.50065816735861, -13.420432414665946, 13.767442916389559)

# %%
x = np.random.randn(100)
y = np.random.randn(100)
label = np.random.randint(2, size=100)
sz = np.random.rand(100)*100

plt.scatter(x, y, c=label, s=sz*3)
plt.colorbar()

# %% [markdown]
# ### 한글 출력

# %%
import matplotlib.font_manager as fm

# prop=fm.FontProperties(fname='C:/Windows/Fonts/gulim.ttc')
# prop=fm.FontProperties(fname='C:/Windows/Fonts/Daum_Regular.ttf')
prop=fm.FontProperties(fname='C:/Windows/Fonts/NanumBarunpenR.ttf')

plt.title('헬로 플롯! (Hello, plot!)', fontproperties=prop, fontsize=20)
# fontproperties 뒤에 fontsize 가 나와야 함
plt.scatter(np.random.randn(100), np.random.randn(100), c=np.random.randn(100), s=50, alpha=0.5)
plt.xlabel('안녕하세요', fontproperties=prop)
plt.legend(['하나'], prop=prop)

# %% [markdown]
# ### 막대 그래프
# - bar(), barh()

# %%
plt.bar(range(20), np.random.randint(10,size=20), color='#00ff00')
# Out:
# <BarContainer object of 20 artists>

# %%
plt.barh(range(10), np.random.randint(10,size=10))
# Out:
# <BarContainer object of 10 artists>

# %%
a = np.random.randint(10,size=10)
b = np.random.randint(10,size=10)

plt.bar(range(10), a, color='blue')
plt.bar(range(10), b, bottom=a, color='pink')
plt.legend(['Man', 'Woman'])

# %% [markdown]
# ### 히스토그램
# - 값들을 구간으로 나눠서 갯수를 막대그래프로 보여준다.

# %%
a = np.random.randn(10000)
display(a.max(), a.min())
# plt.hist(a, bins=30, range=[-3,3])
plt.hist(a, bins=30)
# Out:
# 3.421119194433864
# -4.197240873262347
# (array([  2.,   0.,   3.,   5.,  14.,  20.,  40.,  76., 129., 210., 297.,
#         424., 604., 755., 883., 961., 990., 986., 929., 757., 622., 457.,
#         315., 225., 139.,  81.,  37.,  21.,   9.,   9.]),
#  array([-4.19724087, -3.94329554, -3.6893502 , -3.43540487, -3.18145953,
#         -2.9275142 , -2.67356886, -2.41962352, -2.16567819, -1.91173285,
#         -1.65778752, -1.40384218, -1.14989685, -0.89595151, -0.64200618,
#         -0.38806084, -0.1341155 ,  0.11982983,  0.37377517,  0.6277205 ,
#          0.88166584,  1.13561117,  1.38955651,  1.64350185,  1.89744718,
#          2.15139252,  2.40533785,  2.65928319,  2.91322852,  3.16717386,
#          3.42111919]),
#  <a list of 30 Patch objects>)

# %%
a = np.random.randint(100,size=10000)
plt.hist(a, bins=range(0,101,5))
plt.xticks(range(0,101,5), rotation=90)
print('')

# %%
a = np.random.randn(1000)
b = np.random.normal(10,5,size=1000)
_, bins = np.histogram(np.r_[a,b], 50)

plt.hist(a, bins=bins, alpha=0.3)
plt.hist(b, bins=bins, alpha=0.3)
plt.legend(['zero', 'one'])

# %% [markdown]
# ### 박스 플롯

# %%
a = np.zeros([100,3])
a[:,0] = np.random.randn(100)
a[:,1] = np.random.normal(5,2,size=100)
a[:,2] = np.random.normal(10,5,size=100)

plt.boxplot(a)
print('')

# %% [markdown]
# ### imshow()
# - 2차원 형태의 데이터가 있을 때, 2차원 좌표상에서 그림을 그린다.
# - 이미지 출력에도 사용된다.

# %%
a = np.random.randn(64,64)
plt.imshow(a)
plt.colorbar(shrink=0.7)

# %%
a = np.random.randn(64,64)
plt.imshow(a, interpolation='none', vmin=-1, vmax=1)
plt.colorbar(shrink=0.7)

# %%
a = np.random.randn(64,64)
plt.imshow(a, vmin=-1, vmax=1)
plt.colorbar(shrink=0.7)

# %%
a = [[(x-30)**2 - (y-10)**2 for x in range(100)] for y in range(100)]
a = [[np.sin(x*y) for x in range(100)] for y in range(100)]
plt.imshow(a, origin='lower')
plt.colorbar()

# %%
x = np.arange(-1,1,0.1)
y = np.arange(-1,1,0.1)

xx, yy = np.meshgrid(x,y)

a = np.sin(xx*yy)
plt.imshow(a, origin='lower')
plt.colorbar()

# %%
import matplotlib.image as mpimg

img=mpimg.imread('aaron.jpg')
display(img.shape)
# Out:
# (250, 250, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,0], vmin=0, vmax=255, cmap='Reds_r')

# %%
plt.imshow(img[:,:,1], vmin=0, vmax=255, cmap='Greens_r')

# %%
plt.imshow(img[:,:,2], vmin=0, vmax=255, cmap='Blues_r')

# %% [markdown]
# ### 등고선
# - 이차원 평면 상에서 등고선을 그린다.

# %%
x = np.arange(-1,1,0.1)
y = np.arange(-1,1,0.1)

xx, yy = np.meshgrid(x,y)

a = np.sin(xx*yy)
CS = plt.contour(xx, yy, a, levels=np.arange(-1,1,0.2)) # plt.contour(a)
plt.clabel(CS, inline=2, fontsize=10)
plt.colorbar()

# %%
x = np.arange(-1,1,0.1)
y = np.arange(-1,1,0.1)

xx, yy = np.meshgrid(x,y)

a = np.sin(xx*yy)
plt.contourf(xx, yy, a)
plt.colorbar()

# %% [markdown]
# ### cmap
# - 플롯의 색상 범위를 지정한다.
# - https://matplotlib.org/examples/color/colormaps_reference.html
# - 플롯에서 사용한 값에 따라 자동으로 색상영역을 잡는다. (imshow 의 vmin, vmax 참고)

# %% [markdown]
# ### 여러개의 플롯을 한번에 그리기

# %%
fig, axes = plt.subplots(2,2, figsize=[10,8])
display(axes.shape)

axes[0,0].plot([1,2,3,4])
axes[0,1].scatter(np.random.randn(100), np.random.randn(100))
axes[1,0].bar(range(10),range(10))
axes[1,1].imshow(np.random.randn(64,64))

fig.suptitle('TEST', fontsize=20)
axes[0,0].set_title('TEST1')
# Out:
# (2, 2)
# Text(0.5,1,'TEST1')

# %%
fig = plt.figure(figsize=[10,8])
fig.suptitle('TEST', fontsize=20)

plt.subplot(2,2,1)
plt.title('TEST1')
plt.plot([0,1,2,3])

plt.subplot(2,2,2)
plt.title('TEST2')
plt.scatter(np.random.randn(100), np.random.randn(100))

plt.subplot(2,2,3)
plt.title('TEST3')
plt.bar(range(10),range(10))

plt.subplot(2,2,4)
plt.title('TEST4')
plt.imshow(np.random.randn(64,64))
plt.colorbar()

# %%
X = np.random.randn(100,6)

for i in range(6):
    plt.subplot(3,2,i+1)
    plt.title(i)
    plt.plot(X[:,i],color = "r")
#     plt.plot(X[:, j],color = "b")

# %% [markdown]
# ### 텍스트와 화살표 그리기

# %%
plt.axis([-10,10,-10,10])
plt.vlines([0,5,-5],-10,10,linestyles=':')
plt.hlines([0,5,-5],-10,10,linestyles=':')

plt.text(0,0,'안녕하세요',fontproperties=prop,fontsize=20,va='center',ha='center')
plt.annotate('원점',xy=(0,0),xytext=(5,5),arrowprops=dict(facecolor='black'),fontproperties=prop)
# Out:
# Text(5,5,'원점')

# %% [markdown]
# ### 플롯을 파일로 저장

# %%
x = np.arange(-1,1,0.1)
y = np.arange(-1,1,0.1)

xx, yy = np.meshgrid(x,y)

a = np.sin(xx*yy)
plt.imshow(a, origin='lower')
plt.colorbar()

plt.savefig('myplot.jpg',dpi=200)

# %% [markdown]
# ### 3차원 그림 맛보기

# %%
from mpl_toolkits.mplot3d import Axes3D, axes3d

fig = plt.figure()
#ax=Axes3D(fig, elev=-152, azim=-26)
ax = Axes3D(fig)

rng = np.arange(-10,10,0.5)
X,Y = np.meshgrid(rng, rng)
Z = 1 / (1+np.exp(-1*(X+Y)))

m = ax.scatter(X,Y,Z, s=5)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# Out:
# Text(0.5,0,'Z')
