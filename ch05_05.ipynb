# %% [markdown]
# ## CHAPTER 5
# # Getting Started with pandas
# ---
# ## Statistics

# %%
# %pylab inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.DataFrame([[1,2,3],[11,12,np.nan]]) # None or np.nan
display(df)
# Out:
#     0   1    2
# 0   1   2  3.0
# 1  11  12  NaN

# %%
df[0]
df.idxmax()
# Out:
# 0    1
# 1    1
# 2    0
# dtype: int64

# %%
df.idxmin()
df.cumsum()
# Out:
#       0     1    2
# 0   1.0   2.0  3.0
# 1  12.0  14.0  NaN

# %%
df[0].argmin(), df[0].argmax()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
# (0, 1)

# %%
df.median()
### functions list is at 139 page
# Out:
# 0    6.0
# 1    7.0
# 2    3.0
# dtype: float64

# %% [markdown]
# #### 설치이력
# pip install fix-yahoo-finance<br>
# pip list<br>
# => pandas-datareader (0.2.1)<br>
# pip install --upgrade pandas_datareader<br>
# 마지막에 실패함!!

# %%
# the files are downloaded at "https://github.com/wesm/pydata-book/tree/1st-edition/ch05"
price = pd.read_pickle('yahoo_price.pkl')
volume = pd.read_pickle('yahoo_volume.pkl')

# %%
volume
# Out:
#                  AAPL      GOOG       IBM       MSFT
# Date
# 2010-01-04  123432400   3927000   6155300   38409100
# 2010-01-05  150476200   6031900   6841400   49749600
# 2010-01-06  138040000   7987100   5605300   58182400
# 2010-01-07  119282800  12876600   5840600   50559700
# 2010-01-08  111902700   9483900   4197200   51197400
# 2010-01-11  115557400  14479800   5730400   68754700
# 2010-01-12  148614900   9742900   8081500   65912100
# 2010-01-13  151473000  13041800   6455400   51863500
# 2010-01-14  108223500   8511900   7111800   63228100
# 2010-01-15  148516900  10909600   8494400   79913200
# 2010-01-19  182501900   8665700  13916200   46575700
# 2010-01-20  153038200   6525700  15197500   54849500
# 2010-01-21  152038600  12662600   9608600   73086700
# 2010-01-22  220441900  13651700  10088600  102004600
# 2010-01-25  266424900   8872800   5738500   63373000
# 2010-01-26  466777500   8743600   7135300   66639900
# 2010-01-27  430642100   7958400   8719200   63949500
# ...

# %%
display(price.head())
returns = price.pct_change()
display(returns.head())
# Out:
#                  AAPL        GOOG         IBM       MSFT
# Date
# 2010-01-04  27.990226  313.062468  113.304536  25.884104
# 2010-01-05  28.038618  311.683844  111.935822  25.892466
# 2010-01-06  27.592626  303.826685  111.208683  25.733566
# 2010-01-07  27.541619  296.753749  110.823732  25.465944
# 2010-01-08  27.724725  300.709808  111.935822  25.641571
#                 AAPL      GOOG       IBM      MSFT
# Date
# 2010-01-04       NaN       NaN       NaN       NaN
# 2010-01-05  0.001729 -0.004404 -0.012080  0.000323
# 2010-01-06 -0.015906 -0.025209 -0.006496 -0.006137
# 2010-01-07 -0.001849 -0.023280 -0.003462 -0.010400
# 2010-01-08  0.006648  0.013331  0.010035  0.006897

# %% [markdown]
# ### convariance
# $ cov(X,Y) = \frac{1}{N} \sum_{i=1}^{N} \{(x_i-E(X) (y_i-E(Y))\}$
#
# ### correlation
# $ corr(X,Y) = \frac{cov(X,Y)}{\sigma_X \sigma_Y} $

# %%
returns.MSFT.corr(returns.IBM)
# Out:
# 0.4997636114415116

# %%
returns.MSFT.cov(returns.IBM)

# %%
returns.corr()
# Out:
#           AAPL      GOOG       IBM      MSFT
# AAPL  1.000000  0.407919  0.386817  0.389695
# GOOG  0.407919  1.000000  0.405099  0.465919
# IBM   0.386817  0.405099  1.000000  0.499764
# MSFT  0.389695  0.465919  0.499764  1.000000

# %%
returns.corrwith(volume)
# Out:
# AAPL   -0.075565
# GOOG   -0.007067
# IBM    -0.204849
# MSFT   -0.092950
# dtype: float64

# %%
ser = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])
ser.unique()
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
ser.value_counts()
ser.isin(['b','c'])
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
data = pd.DataFrame({'Qu1': [1, 3, 4, 3, 4],
        'Qu2': [2, 3, 1, 2, 3],
        'Qu3': [1, 5, 2, 4, 4]})
data.apply(pd.value_counts).fillna(0)
# Out:
#    Qu1  Qu2  Qu3
# 1  1.0  1.0  1.0
# 2  0.0  2.0  1.0
# 3  2.0  2.0  0.0
# 4  2.0  0.0  2.0
# 5  0.0  0.0  1.0
